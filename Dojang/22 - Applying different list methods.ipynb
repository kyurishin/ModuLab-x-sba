# %% [markdown]
# ## 리스트와 튜플 응용하기
#
# 파이썬의 리스트는 생각보다 기능이 많다.
#
# 1. 요소를 추가/삭제 할 수 있다.
# 2. 정보를 조회하는 method(함수)를 제공한다.
# 3. for 반복문과 결합하면 연속적이고 반복되는 값을 손쉽게 처리할 수 있다.
#
# ---
#
# ### 22.1 리스트 조작하기
#
# 아래에 리스트를 조작할때 쓰이는 method를 알아보자.
#
# ---
#
# ### 22.1.1  리스트에 요소 추가하기
#
# * **append**: 요소 하나를 추가
# * **extend**: 리스트를 연결하여 확장
# * **insert**: 특정 인덱스에 요소 추가
#
# ---
#
# ### 22.1.2  리스트에 요소 하나 추가하기
#
# ###### __append(요소)는 리스트 끝에 요소 하나를 추가합니다.__
# ###### 다음은 리스트 [10, 20, 30]에 500을 추가하여 리스트는 [10, 20, 30, 500]이 됩니다 (메서드를 호출한 리스트가 변경되며 새 리스트는 생성되지 않음).
#
# ---

# %%
a = [10, 20, 30]
a.append(500)        # 리스트에 500을 추가하기 위해 append method를 쓴다.
a
[10, 20, 30, 500]
len(a)               # 요소의 갯수를 len()으로 구함
# Out:
# 4

# %% [markdown]
# <img src = https://edu.dojang.io/pluginfile.php/4795/mod_page/content/6/022001.png width = 700 img align = left>

# %%
# 빈 리스트에도 추가 할 수 있다.

a = []
a.append(100)
a
# Out:
# [100]

# %% [markdown]
# ### 22.1.3  리스트 안에 리스트 추가하기
#
# append는 append(리스트)처럼 리스트를 넣으면 리스트 안에 리스트가 들어간다.
# 다음은 리스트 a 안에 [500, 600]이 들어가서 "중첩 리스트"가 된다.

# %%
a = [10, 20, 30]
a.append([500, 600])
a
[10, 20, 30, [500, 600]]
len(a)
4
# Out:
# 4

# %% [markdown]
# <img src = https://edu.dojang.io/pluginfile.php/4795/mod_page/content/6/022002.png width = 700 img align = left>

# %% [markdown]
# ## 22.1.4  리스트 **확장**하기
#
# 그러면 리스트에 요소를 여러 개 추가하려면 어떻게 해야 할까요?
# append를 여러 번 사용하는 방법도 있지만, 추가할 요소가 많은 경우에는 상당히 번거롭습니다. 이때는 **extend**를 사용합니다.
#
# **extend(리스트)는 리스트 끝에 다른 리스트를 연결하여 리스트를 확장합니다.**
# 다음은 리스트 [10, 20, 30]에 다른 리스트 [500, 600]을 연결하여 [10, 20, 30, 500, 600]이 됩니다
# (메서드를 호출한 리스트가 변경되며 새 리스트는 생성되지 않음).

# %%
a = [10, 20, 30]
a.extend([500, 600]) # 중첩 리스트 처럼 하지만 method는 extend이다. 
a
len(a)               # 총 요소의 갯수는 세개에서 다섯개로 늘어났다.
# Out:
# 5

# %% [markdown]
# <img src="https://edu.dojang.io/pluginfile.php/4795/mod_page/content/6/022003.png" width = "700" img align=left>
#
# extend의 동작을 좀 더 정확하게 이야기하면 extend에 전달된 **[500, 600]의 요소를 반복**하면서 **각 요소를 리스트 a에 추가**하는 것입니다.
#
# 따라서 **리스트와 리스트를 연결한 모양**이 됩니다.

# %% [markdown]
# ---
#
# ## 22.1.5  리스트의 특정 인덱스에 요소 추가하기
#
# **append, extend는 리스트 끝에 요소를 추가**합니다.
#
# 그러면 **원하는 위치에 요소를 추가**하는 방법은 없을까요? 이때는 **insert**를 사용합니다.
#
# insert(인덱스, 요소)는 리스트의 특정 인덱스에 요소 하나를 추가합니다.
# 다음은 리스트 [10, 20, 30]의 인덱스 2에 500을 추가하여 [10, 20, 500, 30]이 됩니다.

# %%
a = [10, 20 ,30]
a.insert(2,5)
a
# Out:
# [10, 20, 5, 30]

# %% [markdown]
# <img src="https://edu.dojang.io/pluginfile.php/4795/mod_page/content/6/022004.png" width=700 img align=left>

# %% [markdown]
# #### insert에서 자주 사용하는 패턴은 다음 2가지입니다:
#
# - insert(0, 요소): 리스트의 맨 처음에 요소를 추가
# - insert(len(리스트), 요소): 리스트 끝에 요소를 추가

# %%
# 다음은 리스트 [10, 20, 30]의 맨 처음에 500을 추가합니다.

a = [10, 20, 30]
a.insert(0,500)
a
# Out:
# [500, 10, 20, 30]

# %% [markdown]
# 그리고 insert에 __마지막 인덱스보다 큰 값을 지정하면__ 리스트 끝에 요소 하나를 추가할 수 있습니다.
# 다음은 리스트 [10, 20, 30] 끝에 500을 추가합니다.

# %%
a = [10, 20, 30]
a.insert(len(a),500)      # 500은 30보다 크고 a의 길이 끝에 500을 추가함
a
# Out:
# [10, 20, 30, 500]

# %% [markdown]
# len(리스트)는 마지막 인덱스보다 1이 더 크기 때문에 리스트 끝에 값을 추가할 때 자주 활용합니다.
# 사실 이 방법은 a.append(500)과 같습니다.
#
# 특히 insert는 요소 하나를 추가하므로 insert에 리스트를 넣으면 append처럼 리스트 안에 리스트가 들어갑니다.
# 다음은 리스트 [10, 20, 30]의 인덱스 1에 리스트 [500, 600]을 추가하여 중첩 리스트가 됩니다.

# %%
# insert 메서드를 이용해 중첩 인덱스 1에 리스트 추가하기

a = [10, 20, 30]
a.insert(1, [500, 600]) # 1번째 인덱스에 [500,600]리스트 중첩 추가
a
# Out:
# [10, [500, 600], 20, 30]

# %%
a = [1, 2, 3, 4]
a[1:1] = 500, 600
# 시작 인덱스와 끝 인덱스를 같게 지정하면 요소 여러개를 추가할 수 있다.

a
# Out:
# [1, 500, 600, 2, 3, 4]

# %% [markdown]
# ### 리스트에서 요소 삭제하기
#
# - pop: 마지막 요소 / 특정한 인덱스의 요소를 삭제
# - remove: 특정 값을 찾아서 삭제
#
# #### pop( ) 활용하기: 리스트에서 '특정 인덱스'의 요소를 삭제하기

# %%
a = [10, 20 ,30]
a.pop()            # pop() 메서드를 사용하면 함수를 출력할때 30이 삭제된다.
a
# Out:
# [10, 20]

# %%
a = [100, 200, 300]
a.pop(1)
a                  # pop(1)은 1번째 리스트 요소를 삭제하므로 20이 삭제됬다.
# Out:
# [100, 300]

# %%
a = [1000, 2000, 3000]
del a[1]           # 사실 del을 사용해도 상관없다.
a
# Out:
# [1000, 3000]

# %% [markdown]
# #### remove( ): '특정 값'을 찾아서 삭제하기
#
# remove(값)은 리스트에서 특정 값을 찾아서 삭제합니다.
# 다음은 리스트 [10, 20, 30]에서 20을 삭제하여 [10, 30]이 됩니다.

# %%
a = [10,20,30]
a.remove(20)
a
# Out:
# [10, 30]

# %% [markdown]
# #### 리스트로 Stack 만들기: append()와 pop() 활용하기
#
# A,B,C순으로 요소를 넣으면 블록쌓기 같이 맨 아래가 A, 그 다음 B, C순으로 세워진다.
# █ C  .............................  여기서 append()로 요소를 추가하거나,
# █ B  .............................  pop()으로 요소를 삭제하는게 가능하다.
# █ A  .............................  주의 할 점은 순서대로만 추가 / 삭제가 가능하다는 것.
#
# <img src="https://edu.dojang.io/pluginfile.php/4795/mod_page/content/6/022007.png" width = 500>
#
# #### 리스트로 Queue 만들기: append()와 pop() 활용하기
#
# <img src="https://edu.dojang.io/pluginfile.php/4795/mod_page/content/6/022008.png" width = 500>
#
# 정리하자면, pop(0)는 맨 처음 삽입된 요소를 삭제!
# 큐는 좀 더 효율적으로 사용할 수 있도록 덱(deque, double ended queue)이라는 자료형을 제공합니다.
# 덱은 양쪽 끝에서 추가/삭제가 가능한 자료 구조입니다.

# %% [markdown]
# ![Screenshot%202020-09-24%20at%2019.51.16.png](attachment:Screenshot%202020-09-24%20at%2019.51.16.png)

# %% [markdown]
# #### 리스트에서 특정 값의 인덱스 구하기

# %%
### 기억하기! 인덱스(index, 색인)는 위치 값을 뜻하는데 국어사전 옆면에 ㄱ, ㄴ, ㄷ으로 표시해 놓은 것과 비슷합니다.      
### 여기서 주의할 점은 시퀀스 객체의 인덱스는 항상 0부터 시작한다는 점입니다(대다수의 프로그래밍 언어는 인덱스가 0부터 시작합니다). 

a = [10, 20, 30, 40, 50]     
a.index(30)                      # 리스트 안 20의 인덱스를 구하라!
a
# Out:
# [10, 20, 30, 40, 50]

# %% [markdown]
# #### 리스트에서 특정 값의 갯수 구하기

# %%
a = [10, 20, 30 , 20 , 20, 15]
a.count(20)                      # 20이 리스트에 몇개 있는지 count 해줘
# Out:
# 3

# %% [markdown]
# #### 리스트의 순서를 뒤집기

# %%
a = [1, 2, 3, 4, 5, 6]
a.reverse()                      # 괄호를 절대 잊지 말자...
a
# Out:
# [6, 5, 4, 3, 2, 1]

# %% [markdown]
# #### 리스트의 순서를 정렬하기

# %%
a = [6, 9, 12, 40, 1, 4, 30, 2]
a.sort()                         # 오름차순으로 정렬한다 또는 함수.sort(reverse=False)
a
# Out:
# [1, 2, 4, 6, 9, 12, 30, 40]

# %%
a = [6, 9, 12, 40, 1, 4, 30, 2]
a.sort(reverse=True)             # 내림차순으로 정렬하기 위해선 함수.sort(reverse=True)
a
# Out:
# [40, 30, 12, 9, 6, 4, 2, 1]

# %% [markdown]
# #### 리스트의 모든 요소를 삭제하기 : clear( )

# %%
a = [1, 2, 3, 4, 5, 6]
a.clear()
a
# Out:
# []

# %%
a = [1, 2, 3, 4, 5, 6]
del a[:]               # index 처음 배울때 a[:]와 같이 시작 인덱스와 끝 인덱스를 둘다 생략하면 리스트 전체를 가져온다고 배웠다
a                      # a 리스트 요소 전체를 삭제했더니...
# Out:
# []

# %% [markdown]
# #### 리스트를 슬라이스로 조작하기

# %%
a = [0, 10, 20]
a[len(a):]= [500]      # len(a)는 a 리스트의 길이라고 했다. 여기서 마지막에 500를 추가할 수 있다. 
a
# Out:
# [0, 10, 20, 500]

# %%
a = [10, 20, 30]
a[len(a):] = 40        # 여기서 주의 할 점. 반드시 추가할 요소를 []에 묶어 리스트로 지정해야한다.
a
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-47-7f17ec711578> in <module>
#       1 a = [10, 20, 30]
# ----> 2 a[len(a):] = 40        # 여기서 주의 할 점. 반드시 추가할 요소를 []에 묶어 리스트로 지정해야한다.
#       3 a
#
# TypeError: can only assign an iterable

# %%
a = [10, 20, 30]
a[len(a):] = [40, 50]  # a.extend([40,50])과 같은 효과
a
# Out:
# [10, 20, 30, 40, 50]

# %% [markdown]
# ![Screenshot%202020-09-24%20at%2020.42.02.png](attachment:Screenshot%202020-09-24%20at%2020.42.02.png)

# %% [markdown]
# #### if 조건문으로 list (sequence 객체)가 비어있는지 확인해보기

# %%
seq = []
if not len(seq):
    print(True)
# Out:
# True

# %%
seq = [1,2,3,4]
if seq:
    print(True)
# Out:
# True
