# %%
i = 0                     # 초기식
while i < 10:            # while 조건식
     print('Hello, world!')    # 반복할 코드
     i += 1                    # 변화식
# Out:
# Hello, world!
# Hello, world!
# Hello, world!
# Hello, world!
# Hello, world!
# Hello, world!
# Hello, world!
# Hello, world!
# Hello, world!
# Hello, world!

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
i = 1

while i <= 100:
    print('Hello, World', i)
    i += 2
# Out:
# Hello, World 1
# Hello, World 3
# Hello, World 5
# Hello, World 7
# Hello, World 9
# Hello, World 11
# Hello, World 13
# Hello, World 15
# Hello, World 17
# Hello, World 19
# Hello, World 21
# Hello, World 23
# Hello, World 25
# Hello, World 27
# Hello, World 29
# Hello, World 31
# Hello, World 33
# Hello, World 35
# Hello, World 37
# Hello, World 39
# Hello, World 41
# Hello, World 43
# Hello, World 45
# Hello, World 47
# Hello, World 49
# Hello, World 51
# Hello, World 53
# Hello, World 55
# Hello, World 57
# Hello, World 59
# Hello, World 61
# Hello, World 63
# Hello, World 65
# Hello, World 67
# Hello, World 69
# Hello, World 71
# Hello, World 73
# Hello, World 75
# Hello, World 77
# Hello, World 79
# Hello, World 81
# Hello, World 83
# Hello, World 85
# Hello, World 87
# Hello, World 89
# Hello, World 91
# Hello, World 93
# Hello, World 95
# Hello, World 97
# Hello, World 99

# %%
i = 2

while i <= 100:
    print('Hello, World', i)
    i += i
# Out:
# Hello, World 2
# Hello, World 4
# Hello, World 8
# Hello, World 16
# Hello, World 32
# Hello, World 64

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
count = int(input('반복할 횟수를 입력하시오'))

i = 0

while i < count:
    print('Hello World', i)
    i += 1
# Out:
# 반복할 횟수를 입력하시오10
# Hello World 0
# Hello World 1
# Hello World 2
# Hello World 3
# Hello World 4
# Hello World 5
# Hello World 6
# Hello World 7
# Hello World 8
# Hello World 9

# %%
count = int(input('반복할 횟수를 입력하세요'))

while count > 0:
    print('hello, world', count)
    count -= 1
# Out:
# 반복할 횟수를 입력하세요3
# hello, world 3
# hello, world 2
# hello, world 1

# %% [markdown]
# 17.2 반복 횟수가 정해지지 않은 경우

# %%
import random # 랜덤 모듈을 가져온다
random.random() # 난수 출력
# Out:
# 0.28204457913539693

# %%
# randint 함수를 이용해서 난수를 생성할 범위를 지정해보자

# random.randint()

# random.randint(a, b)는 a와 b사이에 숫자를 생성한다는 뜻

# randint 함수를 이용하면 주사위도 만들 수 있다!

random.randint(1,6) # 주사위는 보통 1-6까지 숫자가 있음.
# Out:
# 1

# %%
import random

i = 0
while i != 3:                        # 3이 나올때까지 숫자값이 나온다.
    i = random.randint(1, 6)
    print(i)
# Out:
# 1
# 1
# 4
# 2
# 4
# 5
# 6
# 4
# 5
# 4
# 3

# %% [markdown]
# ## while 반복문으로 무한 루프 만들기

# %%
while True # while에 True 조건식이 들어오면 무한루프 생성!!!! 조건식을 항상 만족하기 때문에 평생 출력이 되버린다.

# True와 같은 의미인 1 등을 써도 무한루프가 생성된다.

while 1:
    print('looped!')
# Out:
#   File "<ipython-input-17-5ed3251a8761>", line 1
#     while True # while에 True 조건식이 들어오면 무한루프 생성!!!! 조건식을 항상 만족하기 때문에 평생 출력이 되버린다.
#                                                                                 ^
# SyntaxError: invalid syntax

# %%
while 1:
    print('looped!')

# %% [markdown]
# 다음 소스 코드를 완성하여 정수 2 5, 4 4, 8 3, 16 2, 32 1이 각 줄에 출력되게 만드세요.
# while에 조건식은 두 개 지정하고, 두 변수를 모두 변화시켜야 합니다.

# %%
i = 2
j = 5

while i <= 32 or j >= 1:
    print(i,j)
    i *= 2
    j -= 1
# Out:
# 2 5
# 4 4
# 8 3
# 16 2
# 32 1

# %% [markdown]
# 표준 입력으로 금액(정수)이 입력됩니다.
# 1회당 요금은 1,350원이고, 교통카드를 사용했을 때마다의 잔액을 각 줄에 출력하는 프로그램을 만드세요
# (input에서 안내 문자열은 출력하지 않아야 합니다).
# 단, 최초 금액은 출력하지 않아야 합니다.
# 그리고 잔액은 음수가 될 수 없으며 잔액이 부족하면 출력을 끝냅니다.

# %%
balance = int(input())

i = 0

while balance >= i :
    
    print(balance, i)
    balance -= 1350
    i += 1
# Out:
# 10000
# 10000 0
# 8650 1
# 7300 2
# 5950 3
# 4600 4
# 3250 5
# 1900 6
# 550 7

# %% [markdown]
# 먼저 정수가 입력된다고 했으므로 int(input())과 같이 입력 값을 정수로 변환한 뒤 변수에 저장합니다(이하 변수는 amount).
#
# 교통카드를 사용했을 때마다 잔액을 출력해야 하므로 while 반복문을 사용하고, 교통카드를 사용할 수 있는 최소 잔액은 1회 요금과 같은 1,350원이므로 조건식은 amount >= 1350으로 지정하여 1,350원 이상일 때만 반복하도록 만듭니다. 그리고 amount -= 1350과 같이 amount에서 1회 요금을 차감한 뒤 print로 amount의 값을 출력하면 됩니다.
#
# 여기서 최초 금액은 출력하지 않고 사용했을 때마다의 잔액만 출력해야 하므로 amount -= 1350 다음에 print가 와야 합니다. print가 먼저 오면 마지막에 사용했을 때의 잔액은 출력되지 않으므로 주의해야 합니다.

# %%
amount = int(input())

while amount >= 1350:
    amount -= 1350
    print(amount)
# Out:
# 10000
# 8650
# 7300
# 5950
# 4600
# 3250
# 1900
# 550
